# %% [markdown]
# # INE: Población por sexo, municipio, nacionalidad y edad

# %%
import requests
import pandas as pd

# %%
# código de provincias  01 ... 51
codigo_provincias = [format(n, '02d') for n in range(1, 52)]

url_base = 'http://www.ine.es/jaxi/files/_px/es/xls/t20/e245/p05/a2016/l0/000{}002.px?'
url_provincias = [url_base.format(c) for c in codigo_provincias]

# %% [markdown]
# ### Ejemplo con Burgos

# %%
# Provincia de burgos
codigo_provincia = codigo_provincias[8]
url_provincia = url_provincias[8]

# Carga el excel sin las primeras líneas ni las últimas
#df = pd.read_excel(url_provincia, skiprows=6, skip_footer=6, header=[0, 1], squeeze=False)
df = pd.read_excel(url_provincia, skip_footer=6)

# Guarda la cabecera para cambiar el nombre de las columnas
cabecera = df.iloc[5]
provincia = df.iloc[0, 0]
df.columns = df.iloc[6]
# Elimina la cabecera
df = df[7:]

# Da un nombre a la primera columna
df.columns.values[0] = 'Municipio'

# Elimina los espacios antes del municipio
df['Municipio'] = df['Municipio'].str.strip()


df.head()
# Out:
# 6              Municipio   Total Menores de 16 años De 16 a 64 años  \
# 7            Ambos sexos     NaN                NaN             NaN
# 8                  Total  360995              50324          228655
# 9           09001-Abajas      29                  0              15
# 10  09003-Adrada de Haza     222                 19             132
# 11  09006-Aguas Cándidas      58                  2              31
#
# 6  De 65 y más años   Total Menores de 16 años De 16 a 64 años  \
# 7               NaN     NaN                NaN             NaN
# 8             82016  335320              45941          207877
# 9                14      28                  0              14
# 10               71     211                 15             125
# 11               25      58                  2              31
#
# 6  De 65 y más años  Total Menores de 16 años De 16 a 64 años De 65 y más años
# 7               NaN    NaN                NaN             NaN              NaN
# 8             81502  25675               4383           20778              514
# 9                14      1                  0               1                0
# 10               71     11                  4               7                0
# 11               25      0                  0               0                0

# %%
# Filas que empiezan por el código de provincia
subtotales = df.loc[~df['Municipio'].str.startswith(codigo_provincia)]
# Filas que además no contienen 'Total'
subtotales = subtotales.loc[~subtotales['Municipio'].str.contains('Total')]

sub_nombre = subtotales['Municipio'].values
sub_index = subtotales['Municipio'].index

sub_nombre, sub_index
# Out:
# (array(['Ambos sexos', 'Hombres', 'Mujeres'], dtype=object),
#  Int64Index([7, 380, 753], dtype='int64'))

# %%
# Subtotales
# 0: ambos sexos, 1: hombres, 2: mujeres
sub_data = []

for i in range(len(sub_nombre)):
    ini = sub_index[i] + 1
    fin = ini + (sub_index[1] - sub_index[0])
    sub_data.append(df[(df.index > ini) & (df.index < fin - 1)])

sub_data[0].head()
# Out:
# 6                 Municipio Total Menores de 16 años De 16 a 64 años  \
# 9              09001-Abajas    29                  0              15
# 10     09003-Adrada de Haza   222                 19             132
# 11     09006-Aguas Cándidas    58                  2              31
# 12  09007-Aguilar de Bureba    64                  1              37
# 13           09009-Albillos   213                 45             141
#
# 6  De 65 y más años Total Menores de 16 años De 16 a 64 años De 65 y más años  \
# 9                14    28                  0              14               14
# 10               71   211                 15             125               71
# 11               25    58                  2              31               25
# 12               26    59                  0              33               26
# 13               27   212                 45             140               27
#
# 6  Total Menores de 16 años De 16 a 64 años De 65 y más años
# 9      1                  0               1                0
# 10    11                  4               7                0
# 11     0                  0               0                0
# 12     5                  1               4                0
# 13     1                  0               1                0

# %%
# Mezcla las dos cabeceras en una sola

def new_column_names(header, nombre_subtotal, cabecera):
    # La primera columna (municipio) solo aparece una vez sin modicarse
    columnas = [header[0]]
    anterior = None
    
    for nombre, tipo in zip(header[1:], cabecera[1:]):
        if type(tipo) is str:
            anterior = tipo
        else:
            tipo = anterior
        nuevo_nombre = '-'.join([nombre_subtotal, tipo, nombre])
        columnas.append(nuevo_nombre)
    
    return columnas

# %%
# Cambia las columnas de cada subdata

for data, nombre, index in zip(sub_data, sub_nombre, sub_index):
    new_columns = new_column_names(data.columns, nombre, cabecera)
    data.columns = new_columns

# %%
sub_data[0].head()
# Out:
#                   Municipio Ambos sexos-Total-Total  \
# 9              09001-Abajas                      29
# 10     09003-Adrada de Haza                     222
# 11     09006-Aguas Cándidas                      58
# 12  09007-Aguilar de Bureba                      64
# 13           09009-Albillos                     213
#
#    Ambos sexos-Total-Menores de 16 años Ambos sexos-Total-De 16 a 64 años  \
# 9                                     0                                15
# 10                                   19                               132
# 11                                    2                                31
# 12                                    1                                37
# 13                                   45                               141
#
#    Ambos sexos-Total-De 65 y más años Ambos sexos-españoles-Total  \
# 9                                  14                          28
# 10                                 71                         211
# 11                                 25                          58
# 12                                 26                          59
# 13                                 27                         212
#
#    Ambos sexos-españoles-Menores de 16 años  \
# 9                                         0
# 10                                       15
# 11                                        2
# 12                                        0
# 13                                       45
#
#    Ambos sexos-españoles-De 16 a 64 años  \
# 9                                     14
# 10                                   125
# 11                                    31
# 12                                    33
# 13                                   140
#
#    Ambos sexos-españoles-De 65 y más años Ambos sexos-extranjeros-Total  \
# 9                                      14                             1
# 10                                     71                            11
# 11                                     25                             0
# 12                                     26                             5
# 13                                     27                             1
#
#    Ambos sexos-extranjeros-Menores de 16 años  \
# 9                                           0
# 10                                          4
# 11                                          0
# 12                                          1
# 13                                          0
#
#    Ambos sexos-extranjeros-De 16 a 64 años  \
# 9                                        1
# 10                                       7
# 11                                       0
# 12                                       4
# 13                                       1
#
#    Ambos sexos-extranjeros-De 65 y más años
# 9                                         0
# 10                                        0
# 11                                        0
# 12                                        0
# 13                                        0

# %%
# Une todos los sub_data
data = sub_data[0]

for s_data in sub_data[1:]:
    # Une los sub_data
    data = data.merge(s_data, on=['Municipio'])

# Añade la columna Provincia al principio del dataframe final
data.insert(0, 'Provincia', provincia)

# Elimina el código de provincia dejando sólo el nombre
data['Provincia'] = data['Provincia'].str.split('.-').str[-1].str.strip()
# Elimina el código del municipio
data['Municipio'] = data['Municipio'].str.split('-').str[-1]


data.head()
# Out:
#   Provincia          Municipio Ambos sexos-Total-Total  \
# 0    Burgos             Abajas                      29
# 1    Burgos     Adrada de Haza                     222
# 2    Burgos     Aguas Cándidas                      58
# 3    Burgos  Aguilar de Bureba                      64
# 4    Burgos           Albillos                     213
#
#   Ambos sexos-Total-Menores de 16 años Ambos sexos-Total-De 16 a 64 años  \
# 0                                    0                                15
# 1                                   19                               132
# 2                                    2                                31
# 3                                    1                                37
# 4                                   45                               141
#
#   Ambos sexos-Total-De 65 y más años Ambos sexos-españoles-Total  \
# 0                                 14                          28
# 1                                 71                         211
# 2                                 25                          58
# 3                                 26                          59
# 4                                 27                         212
#
#   Ambos sexos-españoles-Menores de 16 años  \
# 0                                        0
# 1                                       15
# 2                                        2
# 3                                        0
# 4                                       45
#
#   Ambos sexos-españoles-De 16 a 64 años  \
# 0                                    14
# 1                                   125
# 2                                    31
# 3                                    33
# 4                                   140
#
#   Ambos sexos-españoles-De 65 y más años                 ...                   \
# 0                                     14                 ...
# 1                                     71                 ...
# 2                                     25                 ...
# 3                                     26                 ...
# 4                                     27                 ...
#
#   Mujeres-Total-De 16 a 64 años Mujeres-Total-De 65 y más años  \
# 0                             4                              6
# 1                            60                             39
# 2                             7                             16
# 3                            14                             14
# 4                            60                             13
#
#   Mujeres-españoles-Total Mujeres-españoles-Menores de 16 años  \
# 0                       9                                    0
# 1                     103                                    8
# 2                      23                                    0
# 3                      26                                    0
# 4                      97                                   25
#
#   Mujeres-españoles-De 16 a 64 años Mujeres-españoles-De 65 y más años  \
# 0                                 3                                  6
# 1                                56                                 39
# 2                                 7                                 16
# 3                                12                                 14
# 4                                59                                 13
#
#   Mujeres-extranjeros-Total Mujeres-extranjeros-Menores de 16 años  \
# 0                         1                                      0
# 1                         5                                      1
# 2                         0                                      0
# 3                         3                                      1
# 4                         1                                      0
#
#   Mujeres-extranjeros-De 16 a 64 años Mujeres-extranjeros-De 65 y más años
# 0                                   1                                    0
# 1                                   4                                    0
# 2                                   0                                    0
# 3                                   2                                    0
# 4                                   1                                    0
#
# [5 rows x 38 columns]

# %% [markdown]
# # Completo

# %%
# Mezcla las dos cabeceras en una sola
def new_column_names(header, nombre_subtotal, cabecera):
    # La primera columna (municipio) solo aparece una vez sin modicarse
    columnas = [header[0]]
    anterior = None

    for nombre, tipo in zip(header[1:], cabecera[1:]):
        if type(tipo) is str:
            anterior = tipo
        else:
            tipo = anterior
        nuevo_nombre = '-'.join([nombre_subtotal, tipo, nombre])
        columnas.append(nuevo_nombre)

    return columnas

# %%
def procesa_provincia(codigo_provincia, url_provincia):
    # Carga el excel sin las primeras líneas ni las últimas
    df = pd.read_excel(url_provincia, skip_footer=6)

    # Guarda la cabecera para cambiar el nombre de las columnas
    cabecera = df.iloc[5]
    provincia = df.iloc[0, 0]
    df.columns = df.iloc[6]
    # Elimina la cabecera
    df = df[7:]

    # Da un nombre a la primera columna
    df.columns.values[0] = 'Municipio'

    # Filas que empiezan por el código de provincia
    subtotales = df.loc[~df['Municipio'].str.startswith('    ' + codigo_provincia)]
    # Filas que además no contienen 'Total'
    subtotales = subtotales.loc[~subtotales['Municipio'].str.contains('Total')]

    sub_nombre = subtotales['Municipio'].values
    sub_index = subtotales['Municipio'].index

    # Subtotales
    # 0: ambos sexos, 1: hombres, 2: mujeres
    sub_data = []

    
    for i in range(len(sub_nombre)):
        ini = sub_index[i] + 1
        fin = ini + (sub_index[1] - sub_index[0])
        sub_data.append(df[(df.index > ini) & (df.index < fin - 1)])

        
    # Cambia las columnas de cada subdata
    for data, nombre, index in zip(sub_data, sub_nombre, sub_index):
        new_columns = new_column_names(data.columns, nombre, cabecera)
        data.columns = new_columns
        
    # Une todos los sub_data
    data = sub_data[0]

    for s_data in sub_data[1:]:
        # Une los sub_data
        data = data.merge(s_data, on=['Municipio'])

    # Añade la columna Provincia al principio del dataframe final
    data.insert(0, 'Provincia', provincia)

    return data

# %%
# código de provincias  01 ... 51
codigo_provincias = [format(n, '02d') for n in range(1, 52)]

url_base = 'http://www.ine.es/jaxi/files/_px/es/xls/t20/e245/p05/a2016/l0/000{}002.px?'
url_provincias = [url_base.format(c) for c in codigo_provincias]

datos_provincias = []

for provincia in zip(codigo_provincias, url_provincias):
    datos_provincia = procesa_provincia(*provincia)
    datos_provincias.append(datos_provincia)

# Dataframe con todas las provincias
datos = pd.concat(datos_provincias)

# Elimina el código de provincia dejando sólo el nombre
datos['Provincia'] = datos['Provincia'].str.split('.-').str[-1].str.strip()
# Elimina el código del municipio
datos['Municipio'] = datos['Municipio'].str.split('-').str[-1]

# Elimina el índice que se ha generado al juntar los dataframes
datos = datos.reset_index(drop=True)

#datos.to_excel("Todas_Provincias.xls")
# Out:
#      Provincia Municipio Ambos sexos-Total-Total  \
# 0  Araba/Álava  Dulantzi                    2856
# 1  Araba/Álava   Amurrio                   10260
# 2  Araba/Álava     Añana                     159
# 3  Araba/Álava   Aramaio                    1502
# 4  Araba/Álava   Armiñón                     234
#
#   Ambos sexos-Total-Menores de 16 años Ambos sexos-Total-De 16 a 64 años  \
# 0                                  694                              1875
# 1                                 1530                              6658
# 2                                    9                               100
# 3                                  265                               935
# 4                                   46                               157
#
#   Ambos sexos-Total-De 65 y más años Ambos sexos-españoles-Total  \
# 0                                287                        2632
# 1                               2072                        9655
# 2                                 50                         151
# 3                                302                        1476
# 4                                 31                         223
#
#   Ambos sexos-españoles-Menores de 16 años  \
# 0                                      625
# 1                                     1399
# 2                                        7
# 3                                      263
# 4                                       45
#
#   Ambos sexos-españoles-De 16 a 64 años  \
# 0                                  1721
# 1                                  6198
# 2                                    94
# 3                                   911
# 4                                   147
#
#   Ambos sexos-españoles-De 65 y más años                 ...                   \
# 0                                    286                 ...
# 1                                   2058                 ...
# 2                                     50                 ...
# 3                                    302                 ...
# 4                                     31                 ...
#
#   Mujeres-Total-De 16 a 64 años Mujeres-Total-De 65 y más años  \
# 0                           917                            148
# 1                          3293                           1137
# 2                            32                             34
# 3                           433                            146
# 4                            76                             17
#
#   Mujeres-españoles-Total Mujeres-españoles-Menores de 16 años  \
# 0                    1281                                  292
# 1                    4866                                  665
# 2                      67                                    4
# 3                     699                                  130
# 4                     108                                   20
#
#   Mujeres-españoles-De 16 a 64 años Mujeres-españoles-De 65 y más años  \
# 0                               842                                147
# 1                              3073                               1128
# 2                                29                                 34
# 3                               423                                146
# 4                                71                                 17
#
#   Mujeres-extranjeros-Total Mujeres-extranjeros-Menores de 16 años  \
# 0                       108                                     32
# 1                       299                                     70
# 2                         4                                      1
# 3                        11                                      1
# 4                         5                                      0
#
#   Mujeres-extranjeros-De 16 a 64 años Mujeres-extranjeros-De 65 y más años
# 0                                  75                                    1
# 1                                 220                                    9
# 2                                   3                                    0
# 3                                  10                                    0
# 4                                   5                                    0
#
# [5 rows x 38 columns]

# %%
datos.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f68f6bd923a6> in <module>()
# ----> 1 datos.head()
#
# NameError: name 'datos' is not defined
